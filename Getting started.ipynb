# %% [markdown]
# # Getting started
#
# 👋 Welcome to Deepnote! If you're new to notebooks, we recommend you browse through this guide and watch the videos (it takes about 5 minutes). You can also pick what's most relevant to you right now and come back anytime to see the rest.

# %% [markdown]
# ## 1. Run a cell 🏃
# Select the code cell below and click _Run_ in the right sidebar. You can also press <kbd>Shift</kbd>+<kbd>Enter</kbd> to run it and move to the next cell.

# %%
import pandas as pd
# Load the data set
df = pd.read_csv ('SF_bikeshare_stations.csv') 
df
# Out:
#     station_id                              name   latitude   longitude  \
# 0            4            Santa Clara at Almaden  37.333988 -121.894902
# 1           37              Cowper at University  37.448598 -122.159504
# 2           35            University and Emerson  37.444521 -122.163093
# 3           32  Castro Street and El Camino Real  37.385956 -122.083678
# 4           84                       Ryland Park  37.342725 -121.895617
# ..         ...                               ...        ...         ...
# 69          61                   2nd at Townsend  37.780526 -122.390288
# 70          67                    Market at 10th  37.776619 -122.417385
# 71          77                 Market at Sansome  37.789625 -122.400811
# 72          90               5th St at Folsom St  37.780148 -122.403158
# 73          91       Cyril Magnin St at Ellis St  37.785908 -122.408891
#
#     dockcount       landmark installation_date
# 0          11       San Jose        2013-08-06
# ...

# %%
result = 3 + 4
result
print('hello')
# Out:
# 7

# %% [markdown]
# ## 2. Upload your data 💽
#
# Access your local files, create data sets or connect to third party services.
#
# <iframe width="640" height="400" src="https://www.youtube.com/embed/RjPPkfQJ154" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>

# %% [markdown]
# ## 3. Work with others 🤝
# Deepnote allows you to collaborate with others in real time. Head to the **Share** menu on the top right and hit **Manage collaborators** to add a friend or a colleague to this project.
#
# <iframe width="640" height="400" src="https://www.youtube.com/embed/udw6J5yDMMs" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>

# %% [markdown]
# ## 4. Become a single-shortcut superuser ⚡
# <iframe width="640" height="400" src="https://www.youtube.com/embed/JSlhQUwmjyA" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>

# %% [markdown]
# Press <kbd>⌘</kbd>+<kbd>P</kbd> or <kbd>Ctrl</kbd>+<kbd>P</kbd> to open the **Command palette** and type in `Add new comment` to say something nice.

# %% [markdown]
# ## 5. Connect integrations 🔗
# Connect your Deepnote projects to other services like BigQuery, Amazon S3 or PostgreSQL.
#
#
#
# <iframe width="640" height="400" src="https://www.youtube.com/embed/fKjS7JYvFr8" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>

# %% [markdown]
# ## 6. Publish your work 📚
# Publish your work & build your own data science portfolio.
#
# <iframe width="640" height="400" src="https://www.youtube.com/embed/xm0sVXsaXKs" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>

# %% [markdown]
# # Great job! 🎉
# <video width='300px' autoplay loop playsinline="" muted="" preload="auto">
#   <source type="video/mp4" src="https://storage.googleapis.com/deepnote-landing/high-five.mp4">
# </video>
#
# Now - you have some work waiting for you, don't you?
# ## Create a new project
# To dive into using Deepnote, [open your dashboard](https://deepnote.com/dashboard) (or just click the logo in the top left corner) and create a new project. The setup takes no time at all, we promise.

# %% [markdown]
# ## Have a question? 🤔
# Hit the question mark in the bottom left corner and **chat with us**! We're always happy to help.
#
# - To learn more, head to our documentation at [docs.deepnote.com](https://docs.deepnote.com/).
# - Come say hi in [Deepnote community](https://community.deepnote.com/c/forum)!
